# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\lyf\Anaconda3\envs\py35\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
log_file = "hw3/logs/PongNoFrameskip-v4/log.csv"
data = pandas.read_csv(log_file, index_col=None, comment='#')
plt.subplot(1,2,1)
plt.plot(data['mean_100_episode_reward'])
plt.subplot(1,2,2)
plt.plot(data['best_mean_reward'])

# %%
data
# Out:
#      Timestep  mean_100_episode_reward  best_mean_reward  episodes  \
# 0       60000               -20.265625              -inf        64
# 1       70000               -20.202703              -inf        74
# 2       80000               -20.176471              -inf        85
# 3       90000               -20.187500              -inf        96
# 4      100000               -20.200000        -20.170000       106
# 5      110000               -20.160000        -20.160000       117
# 6      120000               -20.160000        -20.160000       128
# 7      130000               -20.120000        -20.120000       138
# 8      140000               -20.170000        -20.110000       149
# 9      150000               -20.170000        -20.110000       160
# 10     160000               -20.130000        -20.100000       170
# 11     170000               -20.150000        -20.100000       179
# 12     180000               -20.140000        -20.100000       189
# ...
